# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show

output_notebook()

plot = figure()
plot.circle(x1, x2)

handle = show(plot, notebook_handle=True)

# Update the plot title in the earlier cell
plot.title.text = "New Title"
push_notebook(handle=handle)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2085">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6cf94e25-0185-40ae-a4d1-712d4d0f9b93" data-root-id="2086"></div>

# %%
import random
random.random()
# Out:
# 0.3922132967434282

# %%
x1 = list()
x2 = list()
for i in range(0,1000,1):
    x1.append(random.randint(1,10))
    x2.append(random.randint(11,20))

# %% [markdown]
# # Belajar Python OOP

# %%
class Mahasiswa:
    def __init__ (self, nama, nim, jurusan, ipk):
        self.nama = nama
        self.nim = nim
        self.jurusan =  jurusan
        self.ipk = ipk
        
    def tampil(self):
        print(self.nama)

# %%
karakter("hello").a
# Out:
# 'hello'

# %%
class Hewan:
    
    def __init__(self, nama, jumlah_kakai):
        self.nama = nama
        self.jumlah_kaki = jumlah_kakai
    
    def tampil(self):
        print(self.nama)
        print(self.jumlah_kaki)

# %%
sapi = Hewan("sapi", 4)

# %%
sapi.tampil()
# Out:
# sapi
# 4
